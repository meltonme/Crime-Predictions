# %%
# Imports
import requests
import json
from pprint import pprint
from config import api_key

# %%
# Imports for calculations
import pandas as pd
import numpy as np

# %%
# Base Url for 
url = "https://api.usa.gov/crime/fbi/cde/"

# %%
# Agency Query Url
query = "byStateAbbr"
value = "SC"
agency_query_url = url + "agency/" + query + "/" + value + "?API_KEY=" + api_key

print(agency_query_url)
# Out:
# https://api.usa.gov/crime/fbi/cde/agency/byStateAbbr/SC?API_KEY=VZapwhFihrweB1CK2Aorx06jomfZ97WTTsx2lpjX

# %%
# Get AGENCY data
agency_response = requests.get(agency_query_url)
agency_response_json = agency_response.json()

# Get the JSON format
pprint(agency_response_json)
# Out:
# [{'agency_id': 17442,
#   'agency_name': "Abbeville County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': '34.213809',
#   'longitude': '-82.46046',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0010000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17443,
#   'agency_name': 'Abbeville Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': '34.178154',
#   'longitude': '-82.37939',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0010100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17444,
#   'agency_name': 'Calhoun Falls Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': '34.213809',
#   'longitude': '-82.46046',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0010200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17446,
#   'agency_name': 'Due West Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': '34.213809',
#   'longitude': '-82.46046',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0010400',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17447,
#   'agency_name': 'State Transport Police: Abbeville County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': '34.213809',
#   'longitude': '-82.46046',
#   'nibrs': True,
#   'nibrs_start_date': '2010-08-01T00:00:00.000Z',
#   'ori': 'SC0012600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 35236,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': False,
#   'nibrs_start_date': '2023-01-01T00:00:00.000Z',
#   'ori': 'SC001990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17448,
#   'agency_name': 'Erskine College',
#   'agency_type_name': 'University or College',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': '34.213809',
#   'longitude': '-82.46046',
#   'nibrs': True,
#   'nibrs_start_date': '1996-01-01T00:00:00.000Z',
#   'ori': 'SC0019E00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17450,
#   'agency_name': 'Forestry Commission: Abbeville County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': '34.213809',
#   'longitude': '-82.46046',
#   'nibrs': True,
#   'nibrs_start_date': '1997-01-01T00:00:00.000Z',
#   'ori': 'SC001FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17451,
#   'agency_name': 'Department of Natural Resources: Abbeville County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-02-01T00:00:00.000Z',
#   'ori': 'SC001NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17452,
#   'agency_name': 'Highway Patrol: Abbeville County',
#   'agency_type_name': 'State Police',
#   'county_name': 'ABBEVILLE',
#   'division_name': 'South Atlantic',
#   'latitude': '34.213809',
#   'longitude': '-82.46046',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC001SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17453,
#   'agency_name': "Aiken County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.566933',
#   'longitude': '-81.71162',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0020000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17454,
#   'agency_name': 'Aiken Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0020100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17456,
#   'agency_name': 'North Augusta Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'AIKEN, EDGEFIELD',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0020300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17457,
#   'agency_name': 'Burnettown Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0020400',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17458,
#   'agency_name': 'Jackson Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0020500',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17459,
#   'agency_name': 'New Ellenton Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0020600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17460,
#   'agency_name': 'Salley Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '1992-11-01T00:00:00.000Z',
#   'ori': 'SC0020700',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17461,
#   'agency_name': 'Wagener Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0020800',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17463,
#   'agency_name': 'United States Department of Energy Savannah River Plant',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0021000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17465,
#   'agency_name': 'Perry Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': False,
#   'nibrs_start_date': '1994-01-01T00:00:00.000Z',
#   'ori': 'SC0021400',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17466,
#   'agency_name': 'University of South Carolina: Aiken',
#   'agency_type_name': 'University or College',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.587147',
#   'longitude': '-81.75601',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0021500',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17467,
#   'agency_name': 'State Transport Police: Aiken County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '2003-01-01T00:00:00.000Z',
#   'ori': 'SC0022600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 34935,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': True,
#   'nibrs_start_date': '2021-02-01T00:00:00.000Z',
#   'ori': 'SC002990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17469,
#   'agency_name': 'Forestry Commission: Aiken County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC002FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17470,
#   'agency_name': 'Department of Natural Resources: Aiken County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-03-01T00:00:00.000Z',
#   'ori': 'SC002NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17471,
#   'agency_name': 'Highway Patrol: Aiken County',
#   'agency_type_name': 'State Police',
#   'county_name': 'AIKEN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.550013',
#   'longitude': '-81.632983',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC002SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17472,
#   'agency_name': "Allendale County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'ALLENDALE',
#   'division_name': 'South Atlantic',
#   'latitude': '32.979784',
#   'longitude': '-81.363421',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0030000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17473,
#   'agency_name': 'Allendale Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ALLENDALE',
#   'division_name': 'South Atlantic',
#   'latitude': '32.979784',
#   'longitude': '-81.363421',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0030100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17474,
#   'agency_name': 'Fairfax Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ALLENDALE',
#   'division_name': 'South Atlantic',
#   'latitude': '32.979784',
#   'longitude': '-81.363421',
#   'nibrs': False,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0030200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17475,
#   'agency_name': 'State Transport Police: Allendale County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ALLENDALE',
#   'division_name': 'South Atlantic',
#   'latitude': '32.979784',
#   'longitude': '-81.363421',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC0032600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17477,
#   'agency_name': 'Forestry Commission: Allendale County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ALLENDALE',
#   'division_name': 'South Atlantic',
#   'latitude': '32.979784',
#   'longitude': '-81.363421',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC003FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17478,
#   'agency_name': 'Department of Natural Resources: Allendale County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ALLENDALE',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-06-01T00:00:00.000Z',
#   'ori': 'SC003NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17479,
#   'agency_name': 'Highway Patrol: Allendale County',
#   'agency_type_name': 'State Police',
#   'county_name': 'ALLENDALE',
#   'division_name': 'South Atlantic',
#   'latitude': '32.979784',
#   'longitude': '-81.363421',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC003SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17480,
#   'agency_name': "Anderson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0040000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17481,
#   'agency_name': 'Anderson Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.501434',
#   'longitude': '-82.64977',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0040100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17482,
#   'agency_name': 'Belton Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0040200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17483,
#   'agency_name': 'Honea Path Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ABBEVILLE, ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0040300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17484,
#   'agency_name': 'Pendleton Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0040400',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17485,
#   'agency_name': 'Williamston Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0040500',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17486,
#   'agency_name': 'Iva Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0040600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17490,
#   'agency_name': 'West Pelzer Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.645065',
#   'longitude': '-82.467926',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0041000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 25792,
#   'agency_name': 'Tri-County Technical College',
#   'agency_type_name': 'University or College',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '2015-05-01T00:00:00.000Z',
#   'ori': 'SC0041100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17491,
#   'agency_name': 'State Transport Police: Anderson County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '2003-01-01T00:00:00.000Z',
#   'ori': 'SC0042600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 35232,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': False,
#   'nibrs_start_date': '2023-01-01T00:00:00.000Z',
#   'ori': 'SC004990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17493,
#   'agency_name': 'Forestry Commission: Anderson County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC004FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17494,
#   'agency_name': 'Department of Natural Resources: Anderson County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-01-01T00:00:00.000Z',
#   'ori': 'SC004NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17495,
#   'agency_name': 'Highway Patrol: Anderson County',
#   'agency_type_name': 'State Police',
#   'county_name': 'ANDERSON',
#   'division_name': 'South Atlantic',
#   'latitude': '34.519549',
#   'longitude': '-82.638086',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC004SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17496,
#   'agency_name': "Bamberg County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.203021',
#   'longitude': '-81.053161',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0050000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17497,
#   'agency_name': 'Bamberg Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.203021',
#   'longitude': '-81.053161',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0050100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17498,
#   'agency_name': 'Denmark Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.326126',
#   'longitude': '-81.139946',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0050200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17499,
#   'agency_name': 'Ehrhardt Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.203021',
#   'longitude': '-81.053161',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0050300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17500,
#   'agency_name': 'Olar Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.203021',
#   'longitude': '-81.053161',
#   'nibrs': False,
#   'nibrs_start_date': '1998-01-01T00:00:00.000Z',
#   'ori': 'SC0050400',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17501,
#   'agency_name': 'Denmark Technical College',
#   'agency_type_name': 'University or College',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.203021',
#   'longitude': '-81.053161',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0050500',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17502,
#   'agency_name': 'State Transport Police: Bamberg County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.203021',
#   'longitude': '-81.053161',
#   'nibrs': True,
#   'nibrs_start_date': '2003-02-01T00:00:00.000Z',
#   'ori': 'SC0052600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17504,
#   'agency_name': 'Forestry Commission: Bamberg County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.203021',
#   'longitude': '-81.053161',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC005FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17505,
#   'agency_name': 'Department of Natural Resources: Bamberg County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.203021',
#   'longitude': '-81.053161',
#   'nibrs': True,
#   'nibrs_start_date': '1999-06-01T00:00:00.000Z',
#   'ori': 'SC005NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17506,
#   'agency_name': 'Highway Patrol: Bamberg County',
#   'agency_type_name': 'State Police',
#   'county_name': 'BAMBERG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.203021',
#   'longitude': '-81.053161',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC005SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17507,
#   'agency_name': "Barnwell County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'BARNWELL',
#   'division_name': 'South Atlantic',
#   'latitude': '33.260602',
#   'longitude': '-81.434102',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0060000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17508,
#   'agency_name': 'Barnwell Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BARNWELL',
#   'division_name': 'South Atlantic',
#   'latitude': '33.260602',
#   'longitude': '-81.434102',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0060100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17509,
#   'agency_name': 'Williston Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BARNWELL',
#   'division_name': 'South Atlantic',
#   'latitude': '33.260602',
#   'longitude': '-81.434102',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0060200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17510,
#   'agency_name': 'Blackville Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BARNWELL',
#   'division_name': 'South Atlantic',
#   'latitude': '33.353233',
#   'longitude': '-81.26957',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0060300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17511,
#   'agency_name': 'State Transport Police: Barnwell County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BARNWELL',
#   'division_name': 'South Atlantic',
#   'latitude': '33.260602',
#   'longitude': '-81.434102',
#   'nibrs': True,
#   'nibrs_start_date': '2003-02-01T00:00:00.000Z',
#   'ori': 'SC0062600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 35234,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BARNWELL',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': False,
#   'nibrs_start_date': '2023-01-01T00:00:00.000Z',
#   'ori': 'SC006990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17513,
#   'agency_name': 'Forestry Commission: Barnwell County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BARNWELL',
#   'division_name': 'South Atlantic',
#   'latitude': '33.260602',
#   'longitude': '-81.434102',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC006FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17514,
#   'agency_name': 'Department of Natural Resources: Barnwell County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BARNWELL',
#   'division_name': 'South Atlantic',
#   'latitude': '33.260602',
#   'longitude': '-81.434102',
#   'nibrs': True,
#   'nibrs_start_date': '1999-04-01T00:00:00.000Z',
#   'ori': 'SC006NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17515,
#   'agency_name': 'Highway Patrol: Barnwell County',
#   'agency_type_name': 'State Police',
#   'county_name': 'BARNWELL',
#   'division_name': 'South Atlantic',
#   'latitude': '33.260602',
#   'longitude': '-81.434102',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC006SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17516,
#   'agency_name': "Beaufort County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': '32.358147',
#   'longitude': '-80.68932',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0070000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17517,
#   'agency_name': 'Beaufort Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': '32.358147',
#   'longitude': '-80.68932',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0070100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17518,
#   'agency_name': 'Bluffton Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': '32.358147',
#   'longitude': '-80.68932',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0070200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17519,
#   'agency_name': 'Port Royal Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': '32.358147',
#   'longitude': '-80.68932',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0070300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 25401,
#   'agency_name': 'University of South Carolina: Beaufort',
#   'agency_type_name': 'University or College',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': '32.358147',
#   'longitude': '-80.68932',
#   'nibrs': True,
#   'nibrs_start_date': '2014-01-01T00:00:00.000Z',
#   'ori': 'SC0070500',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17521,
#   'agency_name': 'State Transport Police: Beaufort County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': '32.358147',
#   'longitude': '-80.68932',
#   'nibrs': True,
#   'nibrs_start_date': '2003-06-01T00:00:00.000Z',
#   'ori': 'SC0072600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 35238,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': False,
#   'nibrs_start_date': '2023-01-01T00:00:00.000Z',
#   'ori': 'SC007990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17523,
#   'agency_name': 'Forestry Commission: Beaufort County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': '32.358147',
#   'longitude': '-80.68932',
#   'nibrs': True,
#   'nibrs_start_date': '2004-05-01T00:00:00.000Z',
#   'ori': 'SC007FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17524,
#   'agency_name': 'Department of Natural Resources: Beaufort County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-05-01T00:00:00.000Z',
#   'ori': 'SC007NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17525,
#   'agency_name': 'Highway Patrol: Beaufort County',
#   'agency_type_name': 'State Police',
#   'county_name': 'BEAUFORT',
#   'division_name': 'South Atlantic',
#   'latitude': '32.358147',
#   'longitude': '-80.68932',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC007SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17526,
#   'agency_name': "Berkeley County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.200596',
#   'longitude': '-80.01885',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0080000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17527,
#   'agency_name': 'Moncks Corner Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.194794',
#   'longitude': '-80.00659',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0080100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17528,
#   'agency_name': 'Bonneau Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.2077',
#   'longitude': '-79.953655',
#   'nibrs': False,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0080200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17529,
#   'agency_name': 'Goose Creek Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.2077',
#   'longitude': '-79.953655',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0080300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17530,
#   'agency_name': 'Jamestown Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.2077',
#   'longitude': '-79.953655',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0080400',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17531,
#   'agency_name': 'St. Stephen Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.403343',
#   'longitude': '-79.9215',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0080500',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17532,
#   'agency_name': 'Hanahan Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '32.903206',
#   'longitude': '-80.0083',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0080600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 25402,
#   'agency_name': 'Santee Cooper',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.2077',
#   'longitude': '-79.953655',
#   'nibrs': True,
#   'nibrs_start_date': '2014-10-01T00:00:00.000Z',
#   'ori': 'SC0080800',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17534,
#   'agency_name': 'State Transport Police: Berkeley County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.2077',
#   'longitude': '-79.953655',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC0082600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 28114,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': True,
#   'nibrs_start_date': '2018-10-01T00:00:00.000Z',
#   'ori': 'SC008990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17536,
#   'agency_name': 'Forestry Commission: Berkeley County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.2077',
#   'longitude': '-79.953655',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC008FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17537,
#   'agency_name': 'Department of Natural Resources: Berkeley County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-02-01T00:00:00.000Z',
#   'ori': 'SC008NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17538,
#   'agency_name': 'Highway Patrol: Berkeley County',
#   'agency_type_name': 'State Police',
#   'county_name': 'BERKELEY',
#   'division_name': 'South Atlantic',
#   'latitude': '33.192284',
#   'longitude': '-79.99995',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC008SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17539,
#   'agency_name': "Calhoun County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'CALHOUN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.67478',
#   'longitude': '-80.780347',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0090000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17540,
#   'agency_name': 'Cameron Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'CALHOUN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.67478',
#   'longitude': '-80.780347',
#   'nibrs': True,
#   'nibrs_start_date': '1995-01-01T00:00:00.000Z',
#   'ori': 'SC0090100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17541,
#   'agency_name': 'St. Matthews Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'CALHOUN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.67478',
#   'longitude': '-80.780347',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0090200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17542,
#   'agency_name': 'State Transport Police: Calhoun County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'CALHOUN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.67478',
#   'longitude': '-80.780347',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC0092600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 29274,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'CALHOUN',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': False,
#   'nibrs_start_date': '2019-03-01T00:00:00.000Z',
#   'ori': 'SC009990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17544,
#   'agency_name': 'Forestry Commission: Calhoun County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'CALHOUN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.67478',
#   'longitude': '-80.780347',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC009FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17545,
#   'agency_name': 'Department of Natural Resources: Calhoun County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'CALHOUN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-04-01T00:00:00.000Z',
#   'ori': 'SC009NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17546,
#   'agency_name': 'Highway Patrol: Calhoun County',
#   'agency_type_name': 'State Police',
#   'county_name': 'CALHOUN',
#   'division_name': 'South Atlantic',
#   'latitude': '33.67478',
#   'longitude': '-80.780347',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC009SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17547,
#   'agency_name': "Charleston County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.85609',
#   'longitude': '-79.97933',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0100000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17548,
#   'agency_name': 'Charleston Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'BERKELEY, CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.787556',
#   'longitude': '-79.95888',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0100100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17550,
#   'agency_name': 'Mount Pleasant Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.8015',
#   'longitude': '-79.89017',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0100300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17551,
#   'agency_name': 'Folly Beach Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.800458',
#   'longitude': '-79.94248',
#   'nibrs': False,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0100400',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17552,
#   'agency_name': 'Isle of Palms Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.787678',
#   'longitude': '-79.78928',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0100500',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17553,
#   'agency_name': 'Lincolnville Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'CHARLESTON, DORCHESTER',
#   'division_name': 'South Atlantic',
#   'latitude': '32.800458',
#   'longitude': '-79.94248',
#   'nibrs': False,
#   'nibrs_start_date': '2002-05-01T00:00:00.000Z',
#   'ori': 'SC0100600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17554,
#   'agency_name': 'Sullivans Island Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.800458',
#   'longitude': '-79.94248',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0100700',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17555,
#   'agency_name': 'North Charleston Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'CHARLESTON, DORCHESTER',
#   'division_name': 'South Atlantic',
#   'latitude': '32.87881',
#   'longitude': '-80.01314',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0100800',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17556,
#   'agency_name': 'Medical University of South Carolina',
#   'agency_type_name': 'University or College',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.783016',
#   'longitude': '-79.94534',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0100900',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17558,
#   'agency_name': 'The Citadel',
#   'agency_type_name': 'University or College',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.923866',
#   'longitude': '-80.08792',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0101100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17559,
#   'agency_name': 'Trident Technical College',
#   'agency_type_name': 'University or College',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.9245',
#   'longitude': '-80.03199',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0101200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17560,
#   'agency_name': 'State Ports Authority',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.800458',
#   'longitude': '-79.94248',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0101300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17561,
#   'agency_name': 'Charleston County Aviation Authority',
#   'agency_type_name': 'Other',
#   'county_name': 'CHARLESTON',
#   'division_name': 'South Atlantic',
#   'latitude': '32.800458',
#   'longitude': '-79.94248',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0101500',
#   'region_desc': 'Region III',
# ...
#   'division_name': 'South Atlantic',
#   'latitude': '33.92161',
#   'longitude': '-80.33941',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0430100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17947,
#   'agency_name': 'State Transport Police: Sumter County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'SUMTER',
#   'division_name': 'South Atlantic',
#   'latitude': '33.916046',
#   'longitude': '-80.382472',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC0432600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 30995,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'SUMTER',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': True,
#   'nibrs_start_date': '2020-04-01T00:00:00.000Z',
#   'ori': 'SC043990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17949,
#   'agency_name': 'Forestry Commission: Sumter County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'SUMTER',
#   'division_name': 'South Atlantic',
#   'latitude': '33.916046',
#   'longitude': '-80.382472',
#   'nibrs': True,
#   'nibrs_start_date': '2004-03-01T00:00:00.000Z',
#   'ori': 'SC043FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17950,
#   'agency_name': 'Department of Natural Resources: Sumter County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'SUMTER',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-12-01T00:00:00.000Z',
#   'ori': 'SC043NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17951,
#   'agency_name': 'Highway Patrol: Sumter County',
#   'agency_type_name': 'State Police',
#   'county_name': 'SUMTER',
#   'division_name': 'South Atlantic',
#   'latitude': '33.916046',
#   'longitude': '-80.382472',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC043SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17952,
#   'agency_name': "Union County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'UNION',
#   'division_name': 'South Atlantic',
#   'latitude': '34.690429',
#   'longitude': '-81.615891',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0440000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17953,
#   'agency_name': 'Union Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'UNION',
#   'division_name': 'South Atlantic',
#   'latitude': '34.690429',
#   'longitude': '-81.615891',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0440100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17955,
#   'agency_name': 'Jonesville Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'UNION',
#   'division_name': 'South Atlantic',
#   'latitude': '34.690429',
#   'longitude': '-81.615891',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0440300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17956,
#   'agency_name': 'State Transport Police: Union County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'UNION',
#   'division_name': 'South Atlantic',
#   'latitude': '34.690429',
#   'longitude': '-81.615891',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC0442600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17958,
#   'agency_name': 'Forestry Commission: Union County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'UNION',
#   'division_name': 'South Atlantic',
#   'latitude': '34.690429',
#   'longitude': '-81.615891',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC044FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17959,
#   'agency_name': 'Department of Natural Resources: Union County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'UNION',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-04-01T00:00:00.000Z',
#   'ori': 'SC044NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17960,
#   'agency_name': 'Highway Patrol: Union County',
#   'agency_type_name': 'State Police',
#   'county_name': 'UNION',
#   'division_name': 'South Atlantic',
#   'latitude': '34.690429',
#   'longitude': '-81.615891',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC044SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17961,
#   'agency_name': "Williamsburg County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.626463',
#   'longitude': '-79.716475',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0450000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17962,
#   'agency_name': 'Hemingway Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.626463',
#   'longitude': '-79.716475',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0450100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17963,
#   'agency_name': 'Kingstree Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.626463',
#   'longitude': '-79.716475',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0450200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17965,
#   'agency_name': 'Greeleyville Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.626463',
#   'longitude': '-79.716475',
#   'nibrs': True,
#   'nibrs_start_date': '1996-09-01T00:00:00.000Z',
#   'ori': 'SC0450400',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17966,
#   'agency_name': 'Lane Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.626463',
#   'longitude': '-79.716475',
#   'nibrs': True,
#   'nibrs_start_date': '1997-01-01T00:00:00.000Z',
#   'ori': 'SC0450500',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17967,
#   'agency_name': 'State Transport Police: Williamsburg County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.626463',
#   'longitude': '-79.716475',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC0452600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 34931,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': False,
#   'nibrs_start_date': '2023-01-01T00:00:00.000Z',
#   'ori': 'SC045990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17969,
#   'agency_name': 'Forestry Commission: Williamsburg County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.626463',
#   'longitude': '-79.716475',
#   'nibrs': True,
#   'nibrs_start_date': '2003-12-01T00:00:00.000Z',
#   'ori': 'SC045FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17970,
#   'agency_name': 'Department of Natural Resources: Williamsburg County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-05-01T00:00:00.000Z',
#   'ori': 'SC045NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17971,
#   'agency_name': 'Highway Patrol: Williamsburg County',
#   'agency_type_name': 'State Police',
#   'county_name': 'WILLIAMSBURG',
#   'division_name': 'South Atlantic',
#   'latitude': '33.626463',
#   'longitude': '-79.716475',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC045SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17972,
#   'agency_name': "York County Sheriff's Office",
#   'agency_type_name': 'County',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '34.98478',
#   'longitude': '-81.20186',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0460000',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17973,
#   'agency_name': 'Clover Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '34.97019',
#   'longitude': '-81.183188',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0460100',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17974,
#   'agency_name': 'Fort Mill Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '34.97019',
#   'longitude': '-81.183188',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0460200',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17975,
#   'agency_name': 'Rock Hill Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '34.924366',
#   'longitude': '-81.02726',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0460300',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17976,
#   'agency_name': 'York Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '34.97019',
#   'longitude': '-81.183188',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0460400',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17977,
#   'agency_name': 'Tega Cay Police Department',
#   'agency_type_name': 'City',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '35.033',
#   'longitude': '-81.03521',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0460500',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17978,
#   'agency_name': 'Winthrop University',
#   'agency_type_name': 'University or College',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '34.93855',
#   'longitude': '-81.028625',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC0460600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 33667,
#   'agency_name': 'York Technical College',
#   'agency_type_name': 'University or College',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': True,
#   'nibrs_start_date': '2021-11-01T00:00:00.000Z',
#   'ori': 'SC0460700',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17979,
#   'agency_name': 'State Transport Police: York County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '34.97019',
#   'longitude': '-81.183188',
#   'nibrs': True,
#   'nibrs_start_date': '2004-11-01T00:00:00.000Z',
#   'ori': 'SC0462600',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 28194,
#   'agency_name': 'Department of Health and Environmental Control Drug Control:',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': True,
#   'nibrs_start_date': '2018-12-01T00:00:00.000Z',
#   'ori': 'SC046990X',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17981,
#   'agency_name': 'Forestry Commission: York County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '34.97019',
#   'longitude': '-81.183188',
#   'nibrs': True,
#   'nibrs_start_date': '2004-01-01T00:00:00.000Z',
#   'ori': 'SC046FC00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17982,
#   'agency_name': 'Department of Natural Resources: York County',
#   'agency_type_name': 'Other State Agency',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '33.99802',
#   'longitude': '-81.033936',
#   'nibrs': True,
#   'nibrs_start_date': '1999-05-01T00:00:00.000Z',
#   'ori': 'SC046NR00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 17983,
#   'agency_name': 'Highway Patrol: York County',
#   'agency_type_name': 'State Police',
#   'county_name': 'YORK',
#   'division_name': 'South Atlantic',
#   'latitude': '34.97019',
#   'longitude': '-81.183188',
#   'nibrs': True,
#   'nibrs_start_date': '1991-01-01T00:00:00.000Z',
#   'ori': 'SC046SP00',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'},
#  {'agency_id': 34863,
#   'agency_name': 'Catawba Nation',
#   'agency_type_name': 'Tribal',
#   'county_name': 'NOT SPECIFIED',
#   'division_name': 'South Atlantic',
#   'latitude': None,
#   'longitude': None,
#   'nibrs': False,
#   'nibrs_start_date': '2022-01-01T00:00:00.000Z',
#   'ori': 'SCDI00700',
#   'region_desc': 'Region III',
#   'region_name': 'South',
#   'state_abbr': 'SC',
#   'state_name': 'South Carolina'}]

# %%
ori_list = [agency['ori'] for agency in agency_response_json]
#print("List of ORIs:", ori_list)

# %%
offense = "violent-crime"
start_year = "2013"
end_year = "2023"
crime_responses = []
for ori in ori_list:
    target_url = url + f"summarized/agency/{ori}/{offense}?from={start_year}&to={end_year}&API_KEY={api_key}"

    #print(target_url)
    responses = requests.get(target_url)
    responses_json = responses.json()
    crime_responses.append(responses_json)
# Get the JSON format
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       6 target_url = url + f"summarized/agency/{ori}/{offense}?from={start_year}&to={end_year}&API_KEY={api_key}"
#       8 #print(target_url)
# ----> 9 responses = requests.get(target_url)
#      10 responses_json = responses.json()
#      11 crime_responses.append(responses_json)
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Brittney Watts\anaconda3\envs\dev\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
crime_df = pd.DataFrame()
for responses_json in crime_responses:
    #crime_data = responses_json.get('output', [])
    crime_data_df = pd.DataFrame(responses_json)
    crime_df = pd.concat([crime_df, crime_data_df], ignore_index=True)
print(crime_df.head())
# Out:
#          ori  data_year        offense  cleared  actual
# 0  NC0010000       2013  violent-crime       84     109
# 1  NC0010000       2014  violent-crime       81     123
# 2  NC0010000       2015  violent-crime       97     114
# 3  NC0010000       2016  violent-crime       77      95
# 4  NC0010000       2017  violent-crime       34      46

# %%
#Creating Data frames
agency_df = pd.DataFrame(agency_response_json)
#crime_df = pd.DataFrame(crime_response_json['output'])

#Merging the 2 dataframes together
merge_df = pd.merge(agency_df, crime_df, on='ori', how='inner')
print(merge_df.head())
merge_df.to_csv("Output/merged_data.csv", index_label="")
# Out:
#          ori                       agency_name  agency_id      state_name  \
# 0  NC0010000  Alamance County Sheriff's Office      10873  North Carolina
# 1  NC0010000  Alamance County Sheriff's Office      10873  North Carolina
# 2  NC0010000  Alamance County Sheriff's Office      10873  North Carolina
# 3  NC0010000  Alamance County Sheriff's Office      10873  North Carolina
# 4  NC0010000  Alamance County Sheriff's Office      10873  North Carolina
#
#   state_abbr   division_name region_name region_desc county_name  \
# 0         NC  South Atlantic       South  Region III    ALAMANCE
# 1         NC  South Atlantic       South  Region III    ALAMANCE
# 2         NC  South Atlantic       South  Region III    ALAMANCE
# 3         NC  South Atlantic       South  Region III    ALAMANCE
# 4         NC  South Atlantic       South  Region III    ALAMANCE
#
#   agency_type_name  nibrs          nibrs_start_date   latitude   longitude  \
# 0           County   True  2019-01-01T00:00:00.000Z  36.041974  -79.399935
# 1           County   True  2019-01-01T00:00:00.000Z  36.041974  -79.399935
# 2           County   True  2019-01-01T00:00:00.000Z  36.041974  -79.399935
# 3           County   True  2019-01-01T00:00:00.000Z  36.041974  -79.399935
# 4           County   True  2019-01-01T00:00:00.000Z  36.041974  -79.399935
#
#    data_year        offense  cleared  actual
# 0       2013  violent-crime       84     109
# 1       2014  violent-crime       81     123
# 2       2015  violent-crime       97     114
# 3       2016  violent-crime       77      95
# 4       2017  violent-crime       34      46
